# %% [markdown]
# # HatForge - AI Model Training
#
# This notebook will set up the environment, process the dataset, and train your model using Colab's GPU.
#
# **Instructions:**
# 1. Upload `hatforge_colab.zip` to your Colab environment using the file browser on the left.
# 2. Run the cells below sequentially.

# %%
# 1. Unzip the project files
# !unzip -q -o hatforge_colab.zip -d hatforge/

# %%
# 2. Install required dependencies
# !pip install pretty_midi pandas tqdm

# %%
# 3. Process the GMD Dataset
# (Make sure the groove-v1.0.0-midionly dataset is extracted in data/raw)
print("Processing GMD data...")
# !python hatforge/process_gmd.py

# %%
# 4. Train the Model
print("Starting training loop...")
# !python hatforge/phase4_ai_model/model/train.py

# %%
# 5. Export to ONNX for JUCE
print("Exporting to ONNX...")
# !python hatforge/phase4_ai_model/model/export_onnx.py

# After this runs, you can download the .onnx file from the files panel!
